# %%
#Importing the Libraries
import numpy as np
import matplotlib as plt
import pandas as pd

#Importing Dataset
dataset=pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 15 columns]

# %%
#Number of rows and columns
print("The number of Rows: ",dataset.shape[0])
print("The number of Columns: ",dataset.shape[1])
# Out:
# The number of Rows:  215
# The number of Columns:  15

# %%
#!pip install Descriptive
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Descriptive
#   Downloading descriptive-0.0.0.tar.gz (3.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: PyYAML>=3 in c:\programdata\anaconda3\lib\site-packages (from Descriptive) (6.0.1)
# Collecting boto3<1.10,>=1.7.0 (from Descriptive)
#   Downloading boto3-1.9.253-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting botocore<1.13.0,>=1.12.253 (from boto3<1.10,>=1.7.0->Descriptive)
#   Downloading botocore-1.12.253-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3<1.10,>=1.7.0->Descriptive)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting s3transfer<0.3.0,>=0.2.0 (from boto3<1.10,>=1.7.0->Descriptive)
#   Downloading s3transfer-0.2.1-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\programdata\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.253->boto3<1.10,>=1.7.0->Descriptive) (2.9.0.post0)
# Collecting docutils<0.16,>=0.10 (from botocore<1.13.0,>=1.12.253->boto3<1.10,>=1.7.0->Descriptive)
#   Downloading docutils-0.15.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting urllib3<1.26,>=1.20 (from botocore<1.13.0,>=1.12.253->boto3<1.10,>=1.7.0->Descriptive)
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.13.0,>=1.12.253->boto3<1.10,>=1.7.0->Descriptive) (1.16.0)
# Downloading boto3-1.9.253-py2.py3-none-any.whl (128 kB)
# Downloading botocore-1.12.253-py2.py3-none-any.whl (5.7 MB)
#    ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#    ----------------------- ---------------- 3.4/5.7 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------- 5.7/5.7 MB 17.5 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Downloading s3transfer-0.2.1-py2.py3-none-any.whl (70 kB)
# Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
#    ---------------------------------------- 0.0/547.6 kB ? eta -:--:--
#    --------------------------------------- 547.6/547.6 kB 17.8 MB/s eta 0:00:00
# Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Building wheels for collected packages: Descriptive
#   Building wheel for Descriptive (setup.py): started
#   Building wheel for Descriptive (setup.py): finished with status 'error'
#   Running setup.py clean for Descriptive
# Failed to build Descriptive
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [60 lines of output]
#   C:\ProgramData\anaconda3\Lib\site-packages\setuptools\__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#   C:\ProgramData\anaconda3\Lib\site-packages\setuptools\_distutils\dist.py:261: UserWarning: Unknown distribution option: 'tests_require'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib\miniscule
#   copying src\miniscule\aws.py -> build\lib\miniscule
#   copying src\miniscule\base.py -> build\lib\miniscule
#   copying src\miniscule\__init__.py -> build\lib\miniscule
#   running egg_info
#   writing descriptive.egg-info\PKG-INFO
#   C:\ProgramData\anaconda3\Lib\site-packages\setuptools\_core_metadata.py:161: SetuptoolsDeprecationWarning: Invalid config.
#   !!
#
#           ********************************************************************************
#           newlines are not allowed in `summary` and will break in the future
#           ********************************************************************************
#
#   !!
#     write_field('Summary', single_line(summary))
#   writing dependency_links to descriptive.egg-info\dependency_links.txt
#   writing requirements to descriptive.egg-info\requires.txt
#   writing top-level names to descriptive.egg-info\top_level.txt
#   reading manifest file 'descriptive.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   writing manifest file 'descriptive.egg-info\SOURCES.txt'
#   C:\ProgramData\anaconda3\Lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer or other
#           standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   installing to build\bdist.win-amd64\wheel
#   running install
#   running install_lib
#   creating build\bdist.win-amd64\wheel
#   creating build\bdist.win-amd64\wheel\miniscule
#   copying build\lib\miniscule\aws.py -> build\bdist.win-amd64\wheel\.\miniscule
#   copying build\lib\miniscule\base.py -> build\bdist.win-amd64\wheel\.\miniscule
#   copying build\lib\miniscule\__init__.py -> build\bdist.win-amd64\wheel\.\miniscule
#   running install_data
#   creating build\bdist.win-amd64\wheel\descriptive-0.0.0.data\data
#   error: can't copy 'VERSION': doesn't exist or not a regular file
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for Descriptive
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (Descriptive)

# %%
#Load the User Defined Function
from Descriptive import Descriptive
obj=Descriptive()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 #Load the User Defined Function
# ----> 2 from Descriptive import Descriptive
#       3 obj=Descriptive()
#
# ModuleNotFoundError: No module named 'Descriptive'
